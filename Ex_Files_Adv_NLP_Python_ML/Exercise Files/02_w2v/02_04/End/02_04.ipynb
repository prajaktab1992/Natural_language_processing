# %% [markdown]
# # word2vec: How To Prep Word Vectors For Modeling

# %% [markdown]
# ### Train Our Own Model

# %%
# Read in the data, clean it, split it into train and test sets, and then train a word2vec model
import gensim
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
pd.set_option('display.max_colwidth', 100)

messages = pd.read_csv('../../../data/spam.csv', encoding='latin-1')
messages = messages.drop(labels = ["Unnamed: 2", "Unnamed: 3", "Unnamed: 4"], axis = 1)
messages.columns = ["label", "text"]


messages['text_clean'] = messages['text'].apply(lambda x: gensim.utils.simple_preprocess(x))
X_train, X_test, y_train, y_test = train_test_split(messages['text_clean'],
                                                    messages['label'], test_size=0.2)

w2v_model = gensim.models.Word2Vec(X_train,
                                   size=100,
                                   window=5,
                                   min_count=2)

# %% [markdown]
# ### Prep Word Vectors

# %%
# Generate a list of words the word2vec model learned word vectors for
w2v_model.wv.index2word
# Out:
# ['you',
#  'to',
#  'the',
#  'and',
#  'in',
#  'is',
#  'me',
#  'my',
#  'for',
#  'it',
#  'your',
#  'call',
#  'of',
#  'have',
#  'that',
#  'on',
#  'now',
#  'can',
#  'are',
#  'so',
#  'not',
#  'but',
#  'or',
#  'we',
#  'at',
#  'do',
#  'get',
#  'with',
#  'if',
#  'just',
#  'will',
#  'ur',
#  'be',
#  'no',
#  'this',
#  'gt',
#  'lt',
#  'up',
#  'how',
#  'from',
#  'when',
#  'ok',
#  'go',
#  'free',
#  'what',
#  'out',
#  'all',
#  'll',
#  'got',
#  'like',
#  'am',
#  'day',
#  'then',
#  'come',
#  'good',
#  'know',
#  'he',
#  'time',
#  'its',
#  'there',
#  'was',
#  'only',
#  'love',
#  'send',
#  'text',
#  'want',
#  'as',
#  'by',
#  'txt',
#  'one',
#  'going',
#  'need',
#  'see',
#  'home',
#  'still',
#  'stop',
#  'reply',
#  'she',
#  'sorry',
#  'lor',
#  'today',
#  'mobile',
#  'our',
#  'back',
#  'don',
#  'about',
#  'da',
#  'hi',
#  'dont',
#  'take',
#  'tell',
#  'later',
#  'any',
#  'new',
#  'please',
#  'did',
#  'been',
#  'pls',
#  'think',
#  'her',
#  'here',
#  'week',
#  'they',
#  'phone',
#  'claim',
#  'oh',
#  'ì_',
#  'has',
#  'some',
#  'much',
#  'hey',
#  'hope',
#  'where',
#  'happy',
#  'dear',
#  'an',
#  'well',
#  're',
#  'msg',
#  'give',
#  'who',
#  'night',
#  'great',
#  'too',
#  'him',
#  'more',
#  'way',
#  'had',
#  'prize',
#  'said',
#  'won',
#  'should',
#  'yes',
#  'www',
#  'make',
#  'wat',
#  'tomorrow',
#  'right',
#  've',
#  'yeah',
#  'work',
#  'say',
#  'message',
#  'after',
#  'ask',
#  'number',
#  'really',
#  'cash',
#  'doing',
#  'im',
#  'thanks',
#  'find',
#  'win',
#  'why',
#  'meet',
#  'lol',
#  'life',
#  'already',
#  'them',
#  'anything',
#  'morning',
#  'would',
#  'babe',
#  'com',
#  'last',
#  'also',
#  'nokia',
#  'let',
#  'amp',
#  'cos',
#  'miss',
#  'sure',
#  'every',
#  'very',
#  'something',
#  'over',
#  'keep',
#  'min',
#  'urgent',
#  'before',
#  'went',
#  'wait',
#  'care',
#  'uk',
#  'help',
#  'us',
#  'sent',
#  'pick',
#  'again',
#  'next',
#  'even',
#  'contact',
#  'money',
#  'tonight',
#  'his',
#  'box',
#  'buy',
#  'first',
#  'around',
#  'could',
#  'sleep',
#  'were',
#  'service',
#  'gonna',
#  'chat',
#  'someone',
#  'tone',
#  'off',
#  'place',
#  'wan',
#  'mins',
#  'feel',
#  'wish',
#  'sms',
#  'many',
#  'cant',
#  'per',
#  'ya',
#  'customer',
#  'nice',
#  'other',
#  'things',
#  'coming',
#  'which',
#  'thing',
#  'down',
#  'leave',
#  'always',
#  'late',
#  'soon',
#  'guaranteed',
#  'done',
#  'told',
#  'pm',
#  'try',
#  'th',
#  'st',
#  'friends',
#  'dun',
#  'friend',
#  'ìï',
#  'gud',
#  'ppm',
#  'smile',
#  'same',
#  'people',
#  'hello',
#  'getting',
#  'god',
#  'co',
#  'yet',
#  'lunch',
#  'haha',
#  'thought',
#  'special',
#  'man',
#  'may',
#  'fine',
#  'year',
#  'few',
#  'better',
#  'waiting',
#  'live',
#  'use',
#  'name',
#  'stuff',
#  'days',
#  'person',
#  'cs',
#  'heart',
#  'wk',
#  'holiday',
#  'ill',
#  'thk',
#  'yup',
#  'bit',
#  'having',
#  'being',
#  'class',
#  'meeting',
#  'draw',
#  'finish',
#  'didn',
#  'enjoy',
#  'cool',
#  'job',
#  'pobox',
#  'line',
#  'check',
#  'thats',
#  'end',
#  'house',
#  'dinner',
#  'than',
#  'never',
#  'pa',
#  'account',
#  'long',
#  'lot',
#  'because',
#  'offer',
#  'best',
#  'dat',
#  'trying',
#  'yo',
#  'awarded',
#  'mind',
#  'month',
#  'play',
#  'sir',
#  'might',
#  'po',
#  'video',
#  'world',
#  'chance',
#  'talk',
#  'hrs',
#  'shows',
#  'ever',
#  'guess',
#  'problem',
#  'half',
#  'xxx',
#  'wanna',
#  'another',
#  'jus',
#  'eat',
#  'big',
#  'latest',
#  'lar',
#  'shall',
#  'does',
#  'hear',
#  'easy',
#  'nothing',
#  'shit',
#  'sweet',
#  'rate',
#  'plan',
#  'early',
#  'real',
#  'while',
#  'little',
#  'pay',
#  'left',
#  'princess',
#  'luv',
#  'code',
#  'shopping',
#  'start',
#  'bt',
#  'into',
#  'quite',
#  'everything',
#  'car',
#  'bad',
#  'didnt',
#  'watching',
#  'ah',
#  'forgot',
#  'receive',
#  'nd',
#  'hour',
#  'room',
#  'birthday',
#  'look',
#  'called',
#  'word',
#  'liao',
#  'kiss',
#  'once',
#  'calls',
#  'ringtone',
#  'girl',
#  'those',
#  'xx',
#  'between',
#  'ready',
#  'camera',
#  'thanx',
#  'wont',
#  'town',
#  'fun',
#  'landline',
#  'probably',
#  'mail',
#  'remember',
#  'weekend',
#  'came',
#  'fuck',
#  'apply',
#  'bed',
#  'maybe',
#  'tv',
#  'age',
#  'two',
#  'orange',
#  'cost',
#  'put',
#  'entry',
#  'office',
#  'thank',
#  'dunno',
#  'tones',
#  'baby',
#  'says',
#  'speak',
#  'details',
#  'wife',
#  'plz',
#  'guys',
#  'gift',
#  'bring',
#  'years',
#  'valid',
#  'times',
#  'wot',
#  'watch',
#  'bus',
#  'nite',
#  'means',
#  'dis',
#  'missing',
#  'made',
#  'sexy',
#  'selected',
#  'part',
#  'until',
#  'since',
#  'most',
#  'attempt',
#  'asked',
#  'afternoon',
#  'minutes',
#  'enough',
#  'sat',
#  'til',
#  'aight',
#  'den',
#  'decimal',
#  'collect',
#  'else',
#  'award',
#  'wanted',
#  'hair',
#  'reach',
#  'texts',
#  'boy',
#  'xmas',
#  'actually',
#  'worry',
#  'evening',
#  'shop',
#  'missed',
#  'messages',
#  'wid',
#  'dad',
#  'join',
#  'words',
#  'wake',
#  'tmr',
#  'network',
#  'working',
#  'anyway',
#  'answer',
#  'true',
#  'leh',
#  'collection',
#  'stay',
#  'abt',
#  'dude',
#  'wif',
#  'hav',
#  'pain',
#  'till',
#  'guy',
#  'looking',
#  'test',
#  'question',
#  'goes',
#  'hours',
#  'tried',
#  'national',
#  'plus',
#  'either',
#  'comes',
#  'bonus',
#  'online',
#  'okay',
#  'lei',
#  'though',
#  'alright',
#  'important',
#  'price',
#  'goin',
#  'driving',
#  'book',
#  'haf',
#  'address',
#  'mob',
#  'sleeping',
#  'club',
#  'calling',
#  'sad',
#  'both',
#  'family',
#  'school',
#  'without',
#  'double',
#  'optout',
#  'lose',
#  'id',
#  'away',
#  'http',
#  'top',
#  'order',
#  'saw',
#  'juz',
#  'yours',
#  'able',
#  'these',
#  'ard',
#  'havent',
#  'wen',
#  'hurt',
#  'news',
#  'gr',
#  'todays',
#  'movie',
#  'coz',
#  'haven',
#  'update',
#  'hot',
#  'vouchers',
#  'must',
#  'makes',
#  'took',
#  'weekly',
#  'yourself',
#  'yesterday',
#  'story',
#  'head',
#  'together',
#  'making',
#  'minute',
#  'bored',
#  'cause',
#  'beautiful',
#  'awesome',
#  'drive',
#  'colour',
#  'food',
#  'walk',
#  'believe',
#  'await',
#  'everyone',
#  'sch',
#  'wants',
#  'neva',
#  'trip',
#  'busy',
#  'services',
#  'points',
#  'show',
#  'congrats',
#  'music',
#  'pounds',
#  'delivery',
#  'ha',
#  'run',
#  'happen',
#  'nt',
#  'change',
#  'tot',
#  'anyone',
#  'pub',
#  'face',
#  'sae',
#  'brother',
#  'choose',
#  'de',
#  'ring',
#  'saying',
#  'set',
#  'oso',
#  'feeling',
#  'private',
#  'friendship',
#  'pics',
#  'net',
#  'games',
#  'gone',
#  'company',
#  'mum',
#  'date',
#  'camcorder',
#  'finished',
#  'info',
#  'poly',
#  'sister',
#  'alone',
#  'worth',
#  'angry',
#  'carlos',
#  'fri',
#  'huh',
#  'yr',
#  'final',
#  'noe',
#  'tomo',
#  'lucky',
#  'statement',
#  'expires',
#  'type',
#  'boytoy',
#  'ltd',
#  'mates',
#  'available',
#  'dreams',
#  'rs',
#  'party',
#  'girls',
#  'lets',
#  'read',
#  'unsubscribe',
#  'course',
#  'started',
#  'voucher',
#  'case',
#  'charge',
#  'mobileupd',
#  'doesn',
#  'mine',
#  'drop',
#  'sun',
#  'land',
#  'hl',
#  'happened',
#  'leaving',
#  'whats',
#  'game',
#  'tho',
#  'treat',
#  'suite',
#  'row',
#  'taking',
#  'identifier',
#  'smth',
#  'kind',
#  'chikku',
#  'sea',
#  'savamob',
#  'lots',
#  'lovely',
#  'card',
#  'far',
#  'open',
#  'fast',
#  'goodmorning',
#  'hee',
#  'telling',
#  'close',
#  'rite',
#  'wil',
#  'anytime',
#  'unlimited',
#  'weeks',
#  'eve',
#  'light',
#  'na',
#  'parents',
#  'nope',
#  'caller',
#  'player',
#  'second',
#  'hows',
#  'congratulations',
#  'wkly',
#  'college',
#  'each',
#  'whatever',
#  'gbp',
#  'aft',
#  'hmm',
#  'okie',
#  'full',
#  'saturday',
#  'mths',
#  'decided',
#  'old',
#  'freemsg',
#  'offers',
#  'break',
#  'forget',
#  'christmas',
#  'snow',
#  'sounds',
#  'email',
#  'their',
#  'meant',
#  'loving',
#  'wq',
#  'welcome',
#  'tel',
#  'luck',
#  'log',
#  'opt',
#  'outside',
#  'blue',
#  'smoke',
#  'tc',
#  'drink',
#  'invited',
#  'sk',
#  'used',
#  'mobiles',
#  'ten',
#  'post',
#  'almost',
#  'takes',
#  'yrs',
#  'earlier',
#  'finally',
#  'pretty',
#  'fancy',
#  'hard',
#  'currently',
#  'friday',
#  'visit',
#  'sis',
#  'march',
#  'winner',
#  'met',
#  'point',
#  'dating',
#  'isn',
#  'bank',
#  'wonderful',
#  'thinking',
#  'pic',
#  'stupid',
#  'search',
#  'listen',
#  'ass',
#  'support',
#  'mrng',
#  'smiling',
#  'eg',
#  'via',
#  'mean',
#  'msgs',
#  'cum',
#  'hmmm',
#  'prob',
#  'rock',
#  'balance',
#  'lost',
#  'dnt',
#  'discount',
#  'ans',
#  'motorola',
#  'hand',
#  'gas',
#  'enter',
#  'hit',
#  'reason',
#  'found',
#  'quiz',
#  'cut',
#  'checking',
#  'mr',
#  'askd',
#  'mate',
#  'lands',
#  'touch',
#  'knw',
#  'charged',
#  'xy',
#  'download',
#  'chennai',
#  'operator',
#  'picking',
#  'hmv',
#  'frm',
#  'lesson',
#  'needs',
#  'mah',
#  'asking',
#  'yar',
#  'seen',
#  'happiness',
#  'correct',
#  'laptop',
#  'reward',
#  'months',
#  'wine',
#  'valued',
#  'tired',
#  'father',
#  'auction',
#  'police',
#  'gave',
#  'txting',
#  'ts',
#  'slow',
#  'mom',
#  'ago',
#  'gettin',
#  'wit',
#  'custcare',
#  'sex',
#  'grins',
#  'numbers',
#  'match',
#  'fr',
#  'supposed',
#  'heard',
#  'credit',
#  'ipod',
#  'red',
#  'seeing',
#  'knew',
#  'questions',
#  'tickets',
#  'rply',
#  'mu',
#  'jay',
#  'swing',
#  'entered',
#  'surprise',
#  'side',
#  'eh',
#  'ni',
#  'crazy',
#  'ac',
#  'un',
#  'redeemed',
#  'least',
#  'ish',
#  'whole',
#  'song',
#  'phones',
#  'txts',
#  'complimentary',
#  'small',
#  'remove',
#  'loved',
#  'joy',
#  'uncle',
#  'john',
#  'die',
#  'talking',
#  'rakhesh',
#  'comp',
#  'bslvyl',
#  'fucking',
#  'confirm',
#  'possible',
#  'abiola',
#  'em',
#  'gd',
#  'information',
#  'normal',
#  'bill',
#  'drugs',
#  'nyt',
#  'seriously',
#  'lover',
#  'direct',
#  'shower',
#  'representative',
#  'mm',
#  'ho',
#  'otherwise',
#  'fone',
#  'asap',
#  'yep',
#  'loads',
#  'darren',
#  'worries',
#  'within',
#  'etc',
#  'ends',
#  'thinks',
#  'knows',
#  'sort',
#  'hungry',
#  'wishing',
#  'merry',
#  'mayb',
#  'move',
#  'india',
#  'usf',
#  'accept',
#  'content',
#  'trust',
#  'cr',
#  'sony',
#  'write',
#  'paper',
#  'area',
#  'fact',
#  'boss',
#  'felt',
#  'ldn',
#  'wc',
#  'cheap',
#  'tonite',
#  'wow',
#  'wonder',
#  'sitting',
#  'darlin',
#  'worried',
#  'orchard',
#  'plans',
#  'extra',
#  'loan',
#  'gets',
#  'whenever',
#  'frnd',
#  'getzed',
#  'tht',
#  'usual',
#  'oredi',
#  'dream',
#  'bout',
#  'project',
#  'across',
#  'fantastic',
#  'rental',
#  'through',
#  'gotta',
#  'deal',
#  'summer',
#  'rent',
#  'slowly',
#  'valentines',
#  'il',
#  'save',
#  'charity',
#  'cup',
#  'gym',
#  'frnds',
#  'exam',
#  'wrong',
#  'kate',
#  'short',
#  'rcvd',
#  'hospital',
#  'mark',
#  'bb',
#  'sale',
#  'umma',
#  'ringtones',
#  'quick',
#  'monday',
#  'spend',
#  'ge',
#  'buying',
#  'staying',
#  'yahoo',
#  'fixed',
#  'access',
#  'semester',
#  'dogging',
#  'ending',
#  'rates',
#  'complete',
#  'kids',
#  'colleagues',
#  'poor',
#  'lovable',
#  'al',
#  'training',
#  'crave',
#  'leaves',
#  'myself',
#  'woke',
#  'bluetooth',
#  'link',
#  'pete',
#  'meh',
#  'bedroom',
#  'gn',
#  'del',
#  'max',
#  'during',
#  'glad',
#  'figure',
#  'future',
#  'simple',
#  'cd',
#  'south',
#  'ntt',
#  'ex',
#  'anymore',
#  'bold',
#  'mood',
#  'cake',
#  'ave',
#  ...]

# %%
# Generate aggregated sentence vectors based on the word vectors for each word in the sentence
w2v_vect = np.array([np.array([w2v_model.wv[i] for i in ls if i in w2v_model.wv.index2word])
                     for ls in X_test])

# %%
# Why is the length of the sentence different than the length of the sentence vector?
for i, v in enumerate(w2v_vect):
    print(len(X_test.iloc[i]), len(v))
# Out:
# 22 19
# 8 7
# 6 6
# 6 5
# 8 7
# 6 6
# 6 6
# 25 12
# 24 23
# 23 22
# 22 19
# 7 7
# 11 11
# 6 5
# 7 6
# 5 5
# 24 17
# 13 13
# 6 5
# 8 8
# 4 3
# 7 7
# 12 12
# 14 10
# 9 9
# 26 20
# 35 28
# 22 22
# 12 11
# 5 1
# 22 17
# 7 6
# 6 4
# 18 18
# 6 6
# 30 25
# 11 10
# 26 23
# 9 9
# 11 11
# 5 5
# 7 7
# 25 22
# 8 5
# 6 6
# 10 10
# 8 8
# 12 12
# 11 11
# 6 5
# 22 16
# 23 23
# 10 9
# 12 9
# 6 5
# 10 9
# 4 4
# 31 30
# 8 2
# 13 11
# 6 6
# 13 12
# 42 39
# 23 22
# 24 22
# 21 21
# 14 14
# 9 9
# 2 2
# 23 20
# 6 6
# 8 8
# 6 6
# 10 9
# 5 4
# 11 11
# 16 15
# 25 22

# %%
type(w2v_vect[0])
# Out:
# numpy.ndarray

# %%
w2v_vect[0].mean(axis=0)
# Out:
# array([ 0.04926166,  0.21867795,  0.3428932 ,  0.33140454,  0.09872754,
#        -0.4353554 ,  0.3243809 , -0.20690425,  0.31750086, -0.11791521,
#         0.06970374, -0.10528845,  0.27195713,  0.00221676,  0.05412457,
#        -0.05497198, -0.1184602 , -0.11580746,  0.05639719,  0.43767986,
#        -0.01353129,  0.20087206, -0.09427097, -0.07042402, -0.24732323,
#         0.01863688, -0.32070485,  0.0056856 , -0.09420473, -0.03496959,
#         0.35425454, -0.5445007 ,  0.05326956, -0.19236243, -0.02431195,
#         0.02794109,  0.3244538 , -0.36424056, -0.55527186,  0.7253942 ,
#         0.21793163,  0.01648162,  0.32204798,  0.16142635, -0.03493207,
#         0.02341656,  0.24573329,  0.0441433 ,  0.51901203,  0.21757884,
#         0.47430494, -0.1609342 ,  0.0247377 , -0.30021408,  0.3053873 ,
#         0.09433365, -0.2118545 , -0.2909658 ,  0.24171257, -0.10755377,
#        -0.17006397, -0.13193403,  0.1709929 , -0.07988475,  0.55515474,
#         0.1202231 , -0.0583941 ,  0.09652471, -0.20236622, -0.22624287,
#        -0.27823016, -0.05550307,  0.43737015, -0.41110536, -0.03486567,
#        -0.11043125, -0.19315493, -0.47888002,  0.01778251, -0.05230363,
#         0.4924755 ,  0.50578725, -0.53917664,  0.15235922,  0.66872644,
#        -0.32285368,  0.23026606,  0.07713805, -0.29123816, -0.6452504 ,
#        -0.12664546, -0.33668455, -0.1394828 ,  0.5555041 , -0.11829728,
#         0.06334316, -0.48210216,  0.00663541,  0.15297133, -0.16926385],
#       dtype=float32)

# %%
# Compute sentence vectors by averaging the word vectors for the words contained in the sentence
w2v_vect_avg = []

for vect in w2v_vect:
    if len(vect)!=0:
        w2v_vect_avg.append(vect.mean(axis=0))
    else:
        w2v_vect_avg.append(np.zeros(100))

# %%
# Are our sentence vector lengths consistent?
for i, v in enumerate(w2v_vect_avg):
    print(len(X_test.iloc[i]), len(v))
# Out:
# 4 100
# 27 100
# 5 100
# 11 100
# 12 100
# 68 100
# 25 100
# 8 100
# 23 100
# 7 100
# 26 100
# 5 100
# 13 100
# 13 100
# 14 100
# 22 100
# 18 100
# 31 100
# 9 100
# 26 100
# 22 100
# 15 100
# 17 100
# 26 100
# 5 100
# 16 100
# 9 100
# 7 100
# 7 100
# 4 100
# 7 100
# 5 100
# 22 100
# 33 100
# 4 100
# 22 100
# 7 100
# 9 100
# 7 100
# 8 100
# 16 100
# 4 100
# 23 100
# 8 100
# 12 100
# 9 100
# 7 100
# 8 100
# 24 100
# 6 100
# 23 100
# 9 100
# 17 100
# 23 100
# 31 100
# 15 100
# 14 100
# 21 100
# 9 100
# 23 100
# 9 100
# 13 100
# 8 100
# 18 100
# 19 100
# 6 100
# 5 100
# 29 100
# 6 100
# 28 100
# 5 100
# 7 100
# 7 100
# 10 100
# 9 100
# 4 100
# 5 100
# 28 100
# 1 100
# 4 100
# 1 100
# 13 100
# 5 100
# 5 100
# 26 100
# 11 100
# 4 100
# 8 100
# 22 100
# 22 100
# 7 100
# 22 100
# 9 100
# 28 100
# 22 100
# 17 100
# 4 100
# 25 100
# 4 100
# 5 100
# 5 100
# 14 100
# 6 100
# 24 100
# 10 100
# 9 100
# 17 100
# 21 100
# 16 100
# 15 100
# 5 100
# 9 100
# 16 100
# 14 100
# 7 100
# 6 100
# 16 100
# 32 100
# 4 100
# 10 100
# 6 100
# 21 100
# 4 100
# 5 100
# 11 100
# 24 100
# 11 100
# 11 100
# 7 100
# 6 100
# 22 100
# 23 100
# 19 100
# 9 100
# 5 100
# 6 100
# 30 100
# 24 100
# 26 100
# 6 100
# 9 100
# 18 100
# 18 100
# 11 100
# 12 100
# 13 100
# 9 100
# 3 100
# 13 100
# 16 100
# 21 100
# 9 100
# 3 100
# 25 100
# 5 100
# 23 100
# 20 100
# 11 100
# 14 100
# 9 100
# 7 100
# 23 100
# 16 100
# 29 100
# 5 100
# 15 100
# 3 100
# 9 100
# 25 100
# 2 100
# 26 100
# 6 100
# 25 100
# 5 100
# 8 100
# 23 100
# 11 100
# 1 100
# 20 100
# 6 100
# 19 100
# 16 100
# 25 100
# 15 100
# 4 100
# 9 100
# 18 100
# 6 100
# 24 100
# 8 100
# 63 100
# 20 100
# 6 100
# 10 100
# 18 100
# 12 100
# 34 100
# 14 100
# 6 100
# 3 100
# 16 100
# 26 100
# 22 100
# 24 100
# 7 100
# 5 100
# 23 100
# 35 100
# 19 100
# 6 100
# 17 100
# 7 100
# 23 100
# 8 100
# 15 100
# 24 100
# 16 100
# 8 100
# 28 100
# 13 100
# 23 100
# 8 100
# 8 100
# 24 100
# 16 100
# 13 100
# 21 100
# 6 100
# 28 100
# 0 100
# 16 100
# 21 100
# 7 100
# 7 100
# 4 100
# 9 100
# 13 100
# 29 100
# 6 100
# 20 100
# 25 100
# 4 100
# 22 100
# 22 100
# 6 100
# 37 100
# 7 100
# 13 100
# 9 100
# 9 100
# 21 100
# 10 100
# 14 100
# 5 100
# 6 100
# 9 100
# 9 100
# 11 100
# 9 100
# 10 100
# 16 100
# 10 100
# 6 100
# 30 100
# 7 100
# 3 100
# 15 100
# 18 100
# 4 100
# 14 100
# 7 100
# 24 100
# 7 100
# 16 100
# 22 100
# 24 100
# 8 100
# 9 100
# 4 100
# 9 100
# 13 100
# 5 100
# 7 100
# 13 100
# 6 100
# 11 100
# 29 100
# 30 100
# 17 100
# 24 100
# 7 100
# 21 100
# 24 100
# 7 100
# 2 100
# 15 100
# 3 100
# 13 100
# 7 100
# 7 100
# 13 100
# 22 100
# 8 100
# 24 100
# 10 100
# 6 100
# 5 100
# 12 100
# 11 100
# 8 100
# 8 100
# 6 100
# 12 100
# 11 100
# 12 100
# 6 100
# 10 100
# 4 100
# 21 100
# 9 100
# 10 100
# 32 100
# 8 100
# 4 100
# 18 100
# 19 100
# 36 100
# 5 100
# 8 100
# 16 100
# 20 100
# 24 100
# 9 100
# 14 100
# 39 100
# 6 100
# 8 100
# 6 100
# 27 100
# 5 100
# 5 100
# 36 100
# 10 100
# 25 100
# 16 100
# 12 100
# 21 100
# 14 100
# 26 100
# 3 100
# 19 100
# 22 100
# 27 100
# 7 100
# 5 100
# 19 100
# 24 100
# 6 100
# 20 100
# 25 100
# 14 100
# 10 100
# 11 100
# 7 100
# 22 100
# 4 100
# 26 100
# 16 100
# 29 100
# 8 100
# 10 100
# 24 100
# 24 100
# 30 100
# 7 100
# 18 100
# 18 100
# 7 100
# 18 100
# 9 100
# 47 100
# 7 100
# 23 100
# 8 100
# 4 100
# 13 100
# 5 100
# 8 100
# 18 100
# 10 100
# 16 100
# 23 100
# 9 100
# 11 100
# 5 100
# 5 100
# 12 100
# 31 100
# 41 100
# 10 100
# 6 100
# 27 100
# 7 100
# 17 100
# 4 100
# 3 100
# 5 100
# 6 100
# 3 100
# 7 100
# 18 100
# 8 100
# 11 100
# 16 100
# 60 100
# 9 100
# 4 100
# 10 100
# 12 100
# 12 100
# 25 100
# 26 100
# 7 100
# 29 100
# 14 100
# 7 100
# 9 100
# 23 100
# 3 100
# 12 100
# 15 100
# 11 100
# 10 100
# 14 100
# 7 100
# 3 100
# 21 100
# 31 100
# 15 100
# 11 100
# 14 100
# 6 100
# 9 100
# 6 100
# 9 100
# 25 100
# 15 100
# 30 100
# 4 100
# 9 100
# 9 100
# 25 100
# 9 100
# 28 100
# 6 100
# 11 100
# 12 100
# 13 100
# 22 100
# 6 100
# 25 100
# 10 100
# 8 100
# 4 100
# 5 100
# 16 100
# 16 100
# 4 100
# 21 100
# 24 100
# 3 100
# 3 100
# 10 100
# 11 100
# 2 100
# 6 100
# 5 100
# 10 100
# 16 100
# 5 100
# 9 100
# 28 100
# 36 100
# 23 100
# 5 100
# 5 100
# 19 100
# 18 100
# 7 100
# 12 100
# 3 100
# 10 100
# 7 100
# 17 100
# 7 100
# 8 100
# 28 100
# 10 100
# 13 100
# 29 100
# 30 100
# 9 100
# 12 100
# 23 100
# 21 100
# 5 100
# 8 100
# 2 100
# 11 100
# 15 100
# 5 100
# 18 100
# 20 100
# 10 100
# 3 100
# 8 100
# 5 100
# 21 100
# 33 100
# 6 100
# 20 100
# 11 100
# 9 100
# 7 100
# 4 100
# 18 100
# 46 100
# 28 100
# 7 100
# 9 100
# 7 100
# 1 100
# 15 100
# 26 100
# 6 100
# 9 100
# 26 100
# 3 100
# 8 100
# 17 100
# 27 100
# 4 100
# 5 100
# 21 100
# 20 100
# 6 100
# 4 100
# 1 100
# 51 100
# 5 100
# 22 100
# 8 100
# 6 100
# 6 100
# 6 100
# 14 100
# 9 100
# 3 100
# 7 100
# 10 100
# 27 100
# 8 100
# 5 100
# 3 100
# 8 100
# 9 100
# 22 100
# 31 100
# 17 100
# 3 100
# 21 100
# 22 100
# 6 100
# 8 100
# 16 100
# 10 100
# 20 100
# 18 100
# 43 100
# 31 100
# 27 100
# 4 100
# 6 100
# 9 100
# 24 100
# 18 100
# 8 100
# 6 100
# 11 100
# 8 100
# 10 100
# 8 100
# 21 100
# 15 100
# 2 100
# 13 100
